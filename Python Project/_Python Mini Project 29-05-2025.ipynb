# %% [markdown]
# # Pythom Sale Mini Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\ACER\Downloads\Sale.csv")
df
# Out:
#    OrderID   OrderDate Region Salesperson ProductName  Sales
# 0     1001  01-01-2023   East       Alice      Laptop   1200
# 1     1002  16-01-2023   West         Bob      Tablet    800
# 2     1003  31-01-2023  North     Charlie     Monitor    450
# 3     1004  15-02-2023  South       David     Printer    700
# 4     1005  02-03-2023   East         Eve      Laptop   1300
# 5     1006  17-03-2023   West       Frank     Monitor    470
# 6     1007  01-04-2023  North       Grace      Tablet    820
# 7     1008  16-04-2023  South       Heidi     Printer    750
# 8     1009  01-05-2023   East        Ivan      Laptop   1100
# 9     1010  16-05-2023   West        Judy     Monitor    490

# %%
# Convert OrderDate to datetime
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
# Extract month from date
df['Month'] = df['OrderDate'].dt.month

# %%
# Top products
top_products = df.groupby('ProductName')['Sales'].sum().sort_values(ascending=False)

# %%
# Monthly sales
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
# Regional sales
regional_sales = df.groupby('Region')['Sales'].sum()

# %%
# Print outputs
print("\n📦 Top Products by Sales:")
print(top_products)

print("\n📅 Monthly Sales:")
print(monthly_sales)

print("\n🌍 Regional Sales:")
print(regional_sales)
# Out:
# 📦 Top Products by Sales:
# ProductName
# Laptop     3600
# Tablet     1620
# Printer    1450
# Monitor    1410
# Name: Sales, dtype: int64
#
# 📅 Monthly Sales:
# Month
# 1.0    3120
# 2.0    1300
# Name: Sales, dtype: int64
#
# 🌍 Regional Sales:
# Region
# East     3600
# North    1270
# South    1450
# West     1760
# Name: Sales, dtype: int64

# %% [markdown]
# # 📊 Bar Plot

# %%
plt.figure(figsize=(8, 6))
top_products.head(10).plot(kind='bar', color='skyblue', title='Top 10 Products by Sales')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📈 Line Plot

# %%
monthly_sales.plot(kind='line', marker='o', color='orange', title='Monthly Sales Trend')
plt.ylabel('Sales')
plt.xticks(range(1, 13))
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📊 Bar Plot

# %%
regional_sales.plot(kind='bar', color='green', title='Sales by Region')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📌 4. Summary Insights

# %%
print("\n📈 Summary Insights:")
print(f"🔸 Highest-selling product: {top_products.idxmax()}")
print(f"🔸 Month with highest sales: {monthly_sales.idxmax()}")
print(f"🔸 Top-performing region: {regional_sales.idxmax()}")
# Out:
# 📈 Summary Insights:
# 🔸 Highest-selling product: Laptop
# 🔸 Month with highest sales: 1.0
# 🔸 Top-performing region: East
